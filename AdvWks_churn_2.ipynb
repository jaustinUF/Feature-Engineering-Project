# %% [markdown]
# # AdventureWorks Churn Project
# ## Version 2
# > Adapted from : C:\Users\jaust\Dropbox\Temp\Raffaele Miele mentorship\churn_banking_project\data_relationship_correlation\dtc_churn_feature_imporance.py

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier as DTC, plot_tree, export_text
from sklearn.metrics import classification_report, f1_score, roc_auc_score, precision_recall_curve, confusion_matrix
from sklearn.ensemble import RandomForestClassifier

# %%
df = pd.read_csv('/content/drive/MyDrive/Raffaele_Miele_mentorship/AdvWks_churn_project/Project5_with_features.csv') # get dataset
y = df['Ordered_After_2012']                                                   # Define target
X = df.drop(columns=['CustomerKey', 'BirthDate', 'DateFirstPurchase', 'Ordered_After_2012'])  # Drop unnecessary columns
print(f'df shape: {df.shape}   y shape: {y.shape}')
print(f'y value counts\n{y.value_counts()}')
# Out:
# df shape: (2230, 13)   y shape: (2230,)
# y value counts
# Ordered_After_2012
# 1    1968
# 0     262
# Name: count, dtype: int64

# %%
# one-hot encode
categorical_cols = ['MaritalStatus', 'Gender', 'EnglishEducation', 'CommuteDistance']
X_encoded = pd.get_dummies(X, columns=categorical_cols)

# %%
# Split the dataset into train/test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# %%
print(f'y_test value counts\n{y_test.value_counts()}')
# Out:
# y_test value counts
# Ordered_After_2012
# 1    392
# 0     54
# Name: count, dtype: int64

# %%
# create and train model
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
feature_importance = model.feature_importances_
importance_df = pd.DataFrame({'Feature': X_train.columns, 'Importance': feature_importance})
importance_df = importance_df.sort_values(by='Importance', ascending=False)
# print(importance_df.head(10))
print(importance_df)
# Out:
#                                  Feature  Importance
# 1                           YearlyIncome    0.331538
# 2                          TotalChildren    0.169304
# 3                   NumberChildrenAtHome    0.081838
# 4                         HouseOwnerFlag    0.053538
# 5                        MaritalStatus_M    0.031843
# 7                               Gender_F    0.031065
# 11          EnglishEducation_High School    0.031016
# 8                               Gender_M    0.029970
# 14             CommuteDistance_0-1 Miles    0.029409
# 17             CommuteDistance_2-5 Miles    0.029402
# 6                        MaritalStatus_S    0.028762
# 12      EnglishEducation_Partial College    0.026696
# 10      EnglishEducation_Graduate Degree    0.025372
# 9             EnglishEducation_Bachelors    0.024922
# 15             CommuteDistance_1-2 Miles    0.024017
# 18            CommuteDistance_5-10 Miles    0.020061
# 13  EnglishEducation_Partial High School    0.019104
# 16             CommuteDistance_10+ Miles    0.012143
# 0                     Orders_Before_2012    0.000000
